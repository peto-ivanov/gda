# %% [markdown]
# # Challenge
#
# Create a notebook on Google colab, and try to do each of the following tasks with a standard syntax and then with a short syntax in one line.
#
#   * A function that converts amounts in dollars to amounts in euros (take the euro/dollar rate of the day you do the quest).

# %%
# Function that converts EUR to USD.
# Current exchange rate: 1 EUR = 1.17 USD
(lambda eur: eur * 1.17)(25)
# Out:
# 29.25

# %% [markdown]
#   * A function that returns the sum of the even numbers in a list containing integers.

# %%
# Input list
a = [1, 1, 1, 1, 1, 1, 2, 2, 2, 2]

# Expected output: 8
(lambda a: sum([x for x in a if not x % 2]))(a)
# Out:
# 8

# %% [markdown]
#   * A script that converts a list of positive or negative integers into
#     a new list containing absolute values.
#     You can use the following list as an example:

# %%
 test_list = [0, 3, -6, 9, 12, -15, 18, -21, 24, 27]

# %%
[abs(x) for x in test_list]
# Out:
# [0, 3, 6, 9, 12, 15, 18, 21, 24, 27]
